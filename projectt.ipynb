# %%
import pandas as pd

# %%
df=pd.read_csv('/data.csv')

# %%
df
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              1  2020-01-01 00:28:15   2020-01-01 00:33:03                1
# 1              1  2020-01-01 00:35:39   2020-01-01 00:43:04                1
# 2              1  2020-01-01 00:47:41   2020-01-01 00:53:52                1
# 3              1  2020-01-01 00:55:23   2020-01-01 01:00:14                1
# 4              2  2020-01-01 00:01:58   2020-01-01 00:04:16                1
# ...          ...                  ...                   ...              ...
# 124767         2  2020-01-01 17:44:22   2020-01-01 17:55:44                2
# 124768         1  2020-01-01 17:29:03   2020-01-01 18:07:18                4
# 124769         2  2020-01-01 17:09:39   2020-01-01 17:15:52                1
# 124770         1  2020-01-01 17:20:53   2020-01-01 17:37:30                2
# 124771         1  2020-01-01 17:44:11   2020-01-01 18:13:20                4
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                1.20           1                  N           238
# 1                1.20           1                  N           239
# 2                0.60           1                  N           238
# 3                0.80           1                  N           238
# 4                0.00           1                  N           193
# ...               ...         ...                ...           ...
# 124767           1.64           1                  N           144
# 124768          25.20           4                  N           132
# 124769           1.51           1                  N           236
# 124770           8.50           1                  N           138
# 124771          19.40           2                  N           263
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                239             1          6.0    3.0      0.5        1.47
# 1                238             1          7.0    3.0      0.5        1.50
# 2                238             1          6.0    3.0      0.5        1.00
# 3                151             1          5.5    0.5      0.5        1.36
# 4                193             2          3.5    0.5      0.5        0.00
# ...              ...           ...          ...    ...      ...         ...
# 124767           209             2          9.5    0.0      0.5        0.00
# 124768           265             1         80.0    0.0      0.5       15.00
# 124769           140             2          7.0    0.0      0.5        0.00
# 124770           262             1         24.0    3.5      0.5        6.88
# 124771           132             2         52.0    2.5      0.5        0.00
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 0               0.00                    0.3         11.27
# 1               0.00                    0.3         12.30
# 2               0.00                    0.3         10.80
# 3               0.00                    0.3          8.16
# 4               0.00                    0.3          4.80
# ...              ...                    ...           ...
# 124767          0.00                    0.3         12.80
# 124768          6.12                    0.3        101.92
# 124769          0.00                    0.3         10.30
# 124770          6.12                    0.3         41.30
# 124771           NaN                    NaN           NaN
#
#         congestion_surcharge
# 0                        2.5
# 1                        2.5
# 2                        2.5
# 3                        0.0
# 4                        0.0
# ...                      ...
# 124767                   2.5
# 124768                   0.0
# 124769                   2.5
# 124770                   2.5
# 124771                   NaN
#
# [124772 rows x 18 columns]

# %%
#1 Extract all trips with trip_distance larger than 50

df[df['trip_distance']>50]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 23842          2  2020-01-01 01:53:07   2020-01-01 03:54:41                1
# 39013          2  2020-01-01 02:05:07   2020-01-01 03:03:10                1
# 41620          1  2020-01-01 03:05:54   2020-01-01 04:16:26                1
# 58262          2  2020-01-01 05:36:12   2020-01-01 06:40:06                1
# 63024          2  2020-01-01 07:40:30   2020-01-01 08:40:01                1
# 74730          2  2020-01-01 10:45:44   2020-01-01 12:24:33                1
# 75837          1  2020-01-01 11:32:22   2020-01-01 12:46:05                2
# 83924          2  2020-01-01 12:15:03   2020-01-01 13:30:39                4
# 89140          1  2020-01-01 12:08:24   2020-01-01 13:26:44                3
# 89664          2  2020-01-01 13:32:10   2020-01-01 14:52:03                4
# 114849         1  2020-01-01 15:58:25   2020-01-01 17:19:32                2
# 122803         1  2020-01-01 16:54:46   2020-01-01 18:27:49                2
# 165521         2  2020-01-01 23:43:10   2020-01-02 01:01:45                3
# 182932         2  2020-01-02 07:51:07   2020-01-02 08:59:02                1
# 197790         2  2020-01-02 09:32:31   2020-01-02 10:51:16                1
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 23842           52.30           5                  N           262
# 39013           51.23           5                  N           264
# 41620           53.80           5                  N           132
# 58262           55.23           5                  N           132
# 63024           54.19           5                  N           132
# 74730          100.15           1                  N           132
# 75837           61.70           4                  N           162
# 83924           52.69           5                  N           132
# 89140           62.90           1                  N           162
# 89664           76.31           4                  N           132
# 114849          68.20           1                  N           265
# 122803          56.20           5                  N           132
# 165521          73.96           5                  N           219
# 182932          59.32           5                  N           216
# 197790          57.66           5                  N            13
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 23842            265             1        300.0    0.0      0.0       61.78
# 39013            264             1        329.0    0.0      0.5      100.78
# 41620            265             1        250.0    0.0      0.0       53.35
# 58262            265             2        170.0    0.0      0.5        0.00
# 63024            265             1        230.0    0.0      0.0        0.00
# 74730            265             1        253.0    0.0      0.5        5.00
# 75837            265             1        274.0    2.5      0.5        0.00
# 83924            265             1        168.0    0.0      0.5       15.00
# 89140            265             1        163.5    2.5      0.5        0.00
# 89664            265             1        326.0    0.0      0.5        7.00
# 114849           162             1        176.0    2.5      0.5       40.00
# 122803           265             2          0.0    0.0      0.0        0.00
# 165521           265             1        400.0    0.0      0.0       10.00
# 182932           265             1        250.0    0.0      0.0        0.00
# 197790           265             1        250.0    0.0      0.5       10.00
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 23842           6.12                    0.3        370.70
# 39013           6.12                    0.3        436.70
# 41620          16.62                    0.3        320.27
# 58262          18.26                    0.3        189.06
# 63024          12.24                    0.3        242.54
# 74730          22.74                    0.3        281.54
# 75837           2.80                    0.3        280.10
# 83924          23.82                    0.3        207.62
# 89140          80.00                    0.3        246.80
# 89664          16.62                    0.3        350.42
# 114849         62.12                    0.3        281.42
# 122803         24.74                    0.3         25.04
# 165521         22.74                    0.3        433.04
# 182932          0.00                    0.3        250.30
# 197790          0.00                    0.3        263.30
#
#         congestion_surcharge
# 23842                    2.5
# 39013                    0.0
# 41620                    0.0
# 58262                    0.0
# 63024                    0.0
# 74730                    0.0
# 75837                    2.5
# 83924                    0.0
# 89140                    2.5
# 89664                    0.0
# 114849                   2.5
# 122803                   0.0
# 165521                   0.0
# 182932                   0.0
# 197790                   2.5

# %%
#2 Extract all trips where payment_type is missing

df[df['payment_type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge]
# Index: []

# %%
###3 For each (PULocationID, DOLocationID) pair, determine the number of trips


df.groupby(['PULocationID','DOLocationID']).size() # size: counts every number for each value
# Out:
# PULocationID  DOLocationID
# 1             1                38
#               50                1
#               264              15
#               265               1
# 3             3                 1
#                              ...
# 265           215               1
#               230               1
#               248               1
#               264              18
#               265             159
# Length: 11229, dtype: int64

# %%
# 4. Save all rows with missing VendorID, passenger_count, store_and_fwd_flag, payment_type in a new dataframe called bad,
#    and remove those rows from the original dataframe.

nulls = df[df[['VendorID', 'passenger_count', 'store_and_fwd_flag', 'payment_type']].isnull()]

# %%
###Remove the nulls from our dataframe

df = df.dropna(subset=['VendorID', 'passenger_count', 'store_and_fwd_flag', 'payment_type'])

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1         1  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2         1  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3         1  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4         2  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2         1.0                  N         238.0         239.0
# 1            1.2         1.0                  N         239.0         238.0
# 2            0.6         1.0                  N         238.0         238.0
# 3            0.8         1.0                  N         238.0         151.0
# 4            0.0         1.0                  N         193.0         193.0
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           1.0          6.0    3.0      0.5        1.47           0.0
# 1           1.0          7.0    3.0      0.5        1.50           0.0
# 2           1.0          6.0    3.0      0.5        1.00           0.0
# 3           1.0          5.5    0.5      0.5        1.36           0.0
# 4           2.0          3.5    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3         11.27                   2.5
# 1                    0.3         12.30                   2.5
# 2                    0.3         10.80                   2.5
# 3                    0.3          8.16                   0.0
# 4                    0.3          4.80                   0.0

# %%
# 5. Add a duration column storing how long each trip has taken
df['duration'] = (pd.to_datetime(df['tpep_dropoff_datetime']) - pd.to_datetime(df['tpep_pickup_datetime'])).dt.total_seconds()

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
#6 For each pickup location, determine how many trips have started there.

df['PULocationID'].value_counts()
# Out:
# PULocationID
# 132.0    12303
# 186.0    10852
# 161.0    10020
# 48.0      9838
# 237.0     9602
#          ...
# 128.0        1
# 64.0         1
# 46.0         1
# 99.0         1
# 109.0        1
# Name: count, Length: 241, dtype: int64

# %%
# 7. Cluster the pickup time of the day into 30-minute intervals

df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime']) #Make the column datetime so we can extract the intervals
df['pickup_interval'] = df['tpep_pickup_datetime'].dt.floor('30min')

# %%
df
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              1  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1              1  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2              1  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3              1  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4              2  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...          ...                  ...                   ...              ...
# 272455         2  2020-01-02 17:50:06   2020-01-02 18:03:36              2.0
# 272456         2  2020-01-02 17:40:53   2020-01-02 18:02:53              6.0
# 272457         1  2020-01-02 17:09:35   2020-01-02 17:21:19              1.0
# 272458         1  2020-01-02 17:28:23   2020-01-02 17:33:02              1.0
# 272459         1  2020-01-02 17:37:52   2020-01-02 18:02:07              1.0
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.2         1.0                  N         238.0
# 1                 1.2         1.0                  N         239.0
# 2                 0.6         1.0                  N         238.0
# 3                 0.8         1.0                  N         238.0
# 4                 0.0         1.0                  N         193.0
# ...               ...         ...                ...           ...
# 272455            1.3         1.0                  N         162.0
# 272456            1.2         1.0                  N         163.0
# 272457            2.1         1.0                  N         162.0
# 272458            0.4         1.0                  N         143.0
# 272459            8.3         1.0                  N         239.0
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0              239.0           1.0          6.0    3.0      0.5        1.47
# 1              238.0           1.0          7.0    3.0      0.5        1.50
# 2              238.0           1.0          6.0    3.0      0.5        1.00
# 3              151.0           1.0          5.5    0.5      0.5        1.36
# 4              193.0           2.0          3.5    0.5      0.5        0.00
# ...              ...           ...          ...    ...      ...         ...
# 272455         186.0           1.0          9.5    1.0      0.5        2.76
# 272456         230.0           1.0         13.5    1.0      0.5        3.56
# 272457         143.0           1.0         10.0    3.5      0.5        3.55
# 272458         239.0           2.0          4.5    3.5      0.5        0.00
# 272459          69.0           1.0         26.0    3.5      0.5        0.00
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 0                0.0                    0.3         11.27
# 1                0.0                    0.3         12.30
# 2                0.0                    0.3         10.80
# 3                0.0                    0.3          8.16
# 4                0.0                    0.3          4.80
# ...              ...                    ...           ...
# 272455           0.0                    0.3         16.56
# 272456           0.0                    0.3         21.36
# 272457           0.0                    0.3         17.85
# 272458           0.0                    0.3          8.80
# 272459           0.0                    0.3         30.30
#
#         congestion_surcharge  duration     pickup_interval
# 0                        2.5     288.0 2020-01-01 00:00:00
# 1                        2.5     445.0 2020-01-01 00:30:00
# 2                        2.5     371.0 2020-01-01 00:30:00
# 3                        0.0     291.0 2020-01-01 00:30:00
# 4                        0.0     138.0 2020-01-01 00:00:00
# ...                      ...       ...                 ...
# 272455                   2.5     810.0 2020-01-02 17:30:00
# 272456                   2.5    1320.0 2020-01-02 17:30:00
# 272457                   2.5     704.0 2020-01-02 17:00:00
# 272458                   2.5     279.0 2020-01-02 17:00:00
# 272459                   2.5    1455.0 2020-01-02 17:30:00
#
# [272460 rows x 20 columns]

# %%
#8 For each interval, determine the average number of passengers and the average fare amount.
result = df.groupby('pickup_interval').aggregate({'passenger_count':'mean','fare_amount':'mean'})

result.head()
# Out:
#                      passenger_count  fare_amount
# pickup_interval
# 2009-01-01 00:00:00              5.0        52.00
# 2009-01-01 00:30:00              3.0         8.00
# 2019-12-18 15:00:00              1.0         0.01
# 2019-12-18 15:30:00              4.0         2.50
# 2019-12-31 13:00:00              6.0        11.00

# %%
#9 For each payment type and each interval, determine the average fare amount
df.groupby(['payment_type','pickup_interval']).aggregate({'fare_amount':'mean'}) # aggregate: for number of columns>1 ,
                                                                                 # mean: counts the avg
# Out:
#                                   fare_amount
# payment_type pickup_interval
# 1.0          2008-12-31 23:00:00     4.500000
#              2008-12-31 23:30:00    52.000000
#              2019-12-18 15:00:00     0.010000
#              2019-12-18 15:30:00     2.500000
#              2019-12-31 13:30:00    12.000000
# ...                                       ...
# 4.0          2020-01-12 13:30:00    -1.041667
#              2020-01-12 14:00:00    10.909091
#              2020-01-12 14:30:00     2.857143
#              2020-01-12 15:00:00    10.333333
#              2020-01-12 15:30:00    21.916667
#
# [2284 rows x 1 columns]

# %%
# 10. For each payment type, determine the interval when the average fare amount is maximum
max_fare_interval = df.loc[df.groupby('payment_type')['avg_fare_amount'].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d6daca875fa8> in <cell line: 2>()
#       1 # 10. For each payment type, determine the interval when the average fare amount is maximum
# ----> 2 max_fare_interval = df.loc[df.groupby('payment_type')['avg_fare_amount'].idxmax()]
#
# NameError: name 'df' is not defined

# %%
df.groupby(['payment_type','pickup_interval'])['fare_amount'].mean() #for 1 column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ccd2acbf502e> in <cell line: 1>()
# ----> 1 df.groupby(['payment_type','pickup_interval'])['fare_amount'].mean() #gia mia kolona
#
# NameError: name 'df' is not defined

# %%
#12 Find the location with the highest average fare amount
df.groupby(['PULocationID'])['fare_amount'].mean().max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-acf5e4027090> in <cell line: 2>()
#       1 ###12
# ----> 2 df.groupby(['PULocationID'])['fare_amount'].mean().max()
#
# NameError: name 'df' is not defined

# %%
# 13. Build a new dataframe (called common) where, for each pickup location we keep all trips to the 5 most common destinations (i.e. each pickup location can have different common destinations).

trip_counts = df.groupby(['PULocationID', 'DOLocationID']).size().reset_index(name='trip_count')

top_destinations = trip_counts.sort_values(by=['PULocationID', 'trip_count'], ascending=[True, False]).groupby('PULocationID').head(5).reset_index()

common = df.merge(top_destinations[['PULocationID', 'DOLocationID']], on=['PULocationID', 'DOLocationID'])

# %%
common
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             1  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2             1  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3             1  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4             2  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...         ...                  ...                   ...              ...
# 78765         1  2020-01-02 17:24:16   2020-01-02 17:29:36              1.0
# 78766         2  2020-01-02 17:04:53   2020-01-02 17:11:30              2.0
# 78767         2  2020-01-02 17:50:06   2020-01-02 18:03:36              2.0
# 78768         2  2020-01-02 17:40:53   2020-01-02 18:02:53              6.0
# 78769         1  2020-01-02 17:28:23   2020-01-02 17:33:02              1.0
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               1.20         1.0                  N         238.0
# 1               1.20         1.0                  N         239.0
# 2               0.60         1.0                  N         238.0
# 3               0.80         1.0                  N         238.0
# 4               0.00         1.0                  N         193.0
# ...              ...         ...                ...           ...
# 78765           0.60         1.0                  N         186.0
# 78766           1.39         1.0                  N         107.0
# 78767           1.30         1.0                  N         162.0
# 78768           1.20         1.0                  N         163.0
# 78769           0.40         1.0                  N         143.0
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0             239.0           1.0          6.0    3.0      0.5        1.47
# 1             238.0           1.0          7.0    3.0      0.5        1.50
# 2             238.0           1.0          6.0    3.0      0.5        1.00
# 3             151.0           1.0          5.5    0.5      0.5        1.36
# 4             193.0           2.0          3.5    0.5      0.5        0.00
# ...             ...           ...          ...    ...      ...         ...
# 78765         234.0           2.0          5.0    3.5      0.5        0.00
# 78766          79.0           1.0          6.5    1.0      0.5        2.70
# 78767         186.0           1.0          9.5    1.0      0.5        2.76
# 78768         230.0           1.0         13.5    1.0      0.5        3.56
# 78769         239.0           2.0          4.5    3.5      0.5        0.00
#
#        tolls_amount  improvement_surcharge  total_amount  \
# 0               0.0                    0.3         11.27
# 1               0.0                    0.3         12.30
# 2               0.0                    0.3         10.80
# 3               0.0                    0.3          8.16
# 4               0.0                    0.3          4.80
# ...             ...                    ...           ...
# 78765           0.0                    0.3          9.30
# 78766           0.0                    0.3         13.50
# 78767           0.0                    0.3         16.56
# 78768           0.0                    0.3         21.36
# 78769           0.0                    0.3          8.80
#
#        congestion_surcharge  duration     pickup_interval
# 0                       2.5     288.0 2020-01-01 00:00:00
# 1                       2.5     445.0 2020-01-01 00:30:00
# 2                       2.5     371.0 2020-01-01 00:30:00
# 3                       0.0     291.0 2020-01-01 00:30:00
# 4                       0.0     138.0 2020-01-01 00:00:00
# ...                     ...       ...                 ...
# 78765                   2.5     320.0 2020-01-02 17:00:00
# 78766                   2.5     397.0 2020-01-02 17:00:00
# 78767                   2.5     810.0 2020-01-02 17:30:00
# 78768                   2.5    1320.0 2020-01-02 17:30:00
# 78769                   2.5     279.0 2020-01-02 17:00:00
#
# [78770 rows x 20 columns]

# %%
#14. On the common dataframe, for each payment type and each interval, determine the average fare amount
avg_fare_common = common.groupby(['payment_type', 'pickup_interval'])['fare_amount'].mean().reset_index(name='avg_fare_amount')

# %%
#15. Compute the difference of the average fare amount computed in the previous point with those computed at point 9

avg_fare_by_payment_interval = df.groupby(['payment_type', 'pickup_interval'])['fare_amount'].mean().reset_index(name='avg_fare_amount')
fare_diff = avg_fare_common.merge(avg_fare_by_payment_interval, on=['payment_type', 'pickup_interval'], suffixes=('_common', '_all'))
fare_diff['fare_diff'] = fare_diff['avg_fare_amount_common'] - fare_diff['avg_fare_amount_all']

# %%
fare_diff.head()
# Out:
#    payment_type     pickup_interval  avg_fare_amount_common  \
# 0           1.0 2019-12-18 15:00:00                    0.01
# 1           1.0 2019-12-18 15:30:00                    2.50
# 2           1.0 2019-12-31 13:30:00                   10.00
# 3           1.0 2019-12-31 14:00:00                    6.00
# 4           1.0 2019-12-31 16:30:00                    7.00
#
#    avg_fare_amount_all  fare_diff
# 0                 0.01       0.00
# 1                 2.50       0.00
# 2                12.00      -2.00
# 3                12.75      -6.75
# 4                 7.00       0.00

# %%
# 16. Compute the ratio between the differences and the average fare amount from point 9
fare_diff['fare_diff_ratio'] = fare_diff['fare_diff'] / fare_diff['avg_fare_amount_all']

# %%
fare_diff.head()
# Out:
#    payment_type     pickup_interval  avg_fare_amount_common  \
# 0           1.0 2019-12-18 15:00:00                    0.01
# 1           1.0 2019-12-18 15:30:00                    2.50
# 2           1.0 2019-12-31 13:30:00                   10.00
# 3           1.0 2019-12-31 14:00:00                    6.00
# 4           1.0 2019-12-31 16:30:00                    7.00
#
#    avg_fare_amount_all  fare_diff  fare_diff_ratio
# 0                 0.01       0.00         0.000000
# 1                 2.50       0.00         0.000000
# 2                12.00      -2.00        -0.166667
# 3                12.75      -6.75        -0.529412
# 4                 7.00       0.00         0.000000

# %%
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
df = df.sort_values(by=['VendorID', 'tpep_pickup_datetime'])
